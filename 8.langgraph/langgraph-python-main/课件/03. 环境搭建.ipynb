# %% [markdown]
# # 环境搭建

# %% [markdown]
# ## 供应商选择
#
# <img src="./assets/供应商.svg">
#
# |                     | 推理成本               | 开发成本 | 运维成本 | 服务器成本 | 适用                   |
# | ------------------- | ---------------------- | -------- | -------- | ---------- | ---------------------- |
# | 聚合商              | 自有模型低，三方模型高 | 低       | 低       | 无         | 中小型企业             |
# | 源头厂商 + 自建网关 | 低                     | 低       | 低       | 高         | 大中型企业             |
# | 源头厂商 无网关     | 低                     | 中       | 高       | 无         | 学习<br />快速原型迭代 |

# %% [markdown]
# 任务：
# 1. 完成阿里百炼平台的`API-KEY`申请
# 2. 配置环境变量

# %%
# !uv add pydantic-settings==2.14.1
# Out:
# Resolved 175 packages in 19ms
#   × Failed to build `langgraph-python @on @ file:///Users/a123/D%E7%9B%98/%E5%AD%A6%E4%B9%A0/m⠙ Preparing packages... (0/1)
#   │ file:///Users/a123/D%E7%9B%98/%E5%AD%A6%E4%B9%A0/project/python-ai/8.langgraph/langgraph-python-main`
#   ╰─▶ Expected a Python module at:
#       /Users/a123/D盘/学习/project/python-ai/8.langgraph/langgraph-python-main/src/langgraph_python/__init__.py
#
# hint: If you want to add the package regardless of the failed resolution, provide the `--frozen` flag to skip locking and syncing

# %%
# 读取环境变量
from langgraph_python.core.config import openai_settings, anthropic_settings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 读取环境变量
# ----> 2 from langgraph_python.core.config import openai_settings
#
# File ~/D盘/学习/project/python-ai/8.langgraph/langgraph-python-main/src/langgraph_python/core/config.py:8
#       4 class BaseSettingsWithEnv(BaseSettings):
#       5     model_config = {"env_file": ".env", "extra": "ignore"}
# ----> 8 class OpenAISettings(BaseSettingsWithEnv):
#      10     print(model_config)
#      13 class AnthropicSettings(BaseSettingsWithEnv):
#
# File ~/D盘/学习/project/python-ai/8.langgraph/langgraph-python-main/src/langgraph_python/core/config.py:10, in OpenAISettings()
#       8 class OpenAISettings(BaseSettingsWithEnv):
# ---> 10     print(model_config)
#
# NameError: name 'model_config' is not defined

# %%
openai_settings
# Out:
# OpenAISettings(api_key='sk-ws-H.ERPHMEX.BV8I.MEUCIQDgPTioXpcmBP61aFBmUChnJbAyrO251Y9nUuTfw0qRYAIgOWMO_9Ts0WDTcLDwIBp2gVoJW8y4BHgkQ4_HczjTtp8', base_url='', default_model='')

# %%
anthropic_settings
# Out:
# AnthropicSettings(api_key='', base_url='', default_model='')

# %% [markdown]
# ## 监控/评测平台
#
# https://smith.langchain.com/
#
# <img src="./assets/监控平台.svg">
